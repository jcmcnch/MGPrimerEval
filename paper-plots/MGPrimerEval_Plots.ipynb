# %%
#bioGEOTRACES calculations for paper
bgt.summary <- read.delim("/home/jesse/MG-primer-eval/bioGEOTRACES/compute-workflow-intermediate/200206_complete.tsv", header=FALSE)

bgt.arch.all <- bgt.summary[with(bgt.summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R" & V4!="807F" & V4!="1050R" ), ]
bgt.arch.all$V4=factor(bgt.arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R"))

bgt.cyano.all <- bgt.summary[with(bgt.summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"  & V4!="807F" & V4!="1050R"), ]
bgt.cyano.all$V4=factor(bgt.cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

bgt.bact.all <- bgt.summary[with(bgt.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"  & V4!="807F" & V4!="1050R"), ]
bgt.bact.all$V4=factor(bgt.bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

bgt.euk.all <- bgt.summary[with(bgt.summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
bgt.euk.all$V4=factor(bgt.euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, bioGEOTRACES")
print(mean(bgt.arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R")){
    sliced <- bgt.arch.all[with(bgt.arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, bioGEOTRACES")
print(mean(bgt.bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R")){
    sliced <- bgt.bact.all[with(bgt.bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}


print("CYANO summaries, bioGEOTRACES")
print(mean(bgt.cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R")){
    sliced <- bgt.cyano.all[with(bgt.cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, bioGEOTRACES")
print(mean(bgt.euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- bgt.euk.all[with(bgt.euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, bioGEOTRACES"
# [1] 36.90755
# [1] "341F"             "37.7311977715877"
# [1] "785R"            "35.390243902439"
# [1] "515Y"            "33.076512455516"
# [1] "806RB"            "35.8990825688073"
# [1] "926R"             "38.0965517241379"
# [1] "926wF"            "38.0862068965517"
# [1] "1392R"            "41.3566878980892"
# [1] "BACT summaries, bioGEOTRACES"
# [1] 256.8651
# [1] "27F"              "62.8030431107354"
# [1] "338R"             "307.459016393443"
# [1] "341F"             "324.481147540984"
# [1] "785R"             "257.197703035275"
# [1] "515Y"             "273.999180327869"
# [1] "806RB"            "259.331967213115"
# [1] "926R"             "271.861133935908"
# [1] "926wF"            "270.998357963875"
# [1] "1392R"            "277.829508196721"
# [1] "CYANO summaries, bioGEOTRACES"
# [1] 46.27692
# [1] "27F"              "26.2885496183206"
# [1] "338R"             "47.6204576043069"
# [1] "341F"             "49.2996005326232"
# ...

# %%
#All pelagic dataset summaries, overall averages for paper
summary <- read.delim("/home/jesse/MG-primer-eval/BGT-Dimensions-Malaspina-MBARI-TARA-individual-samples.tsv", header=FALSE)

arch.all <- bgt.summary[with(bgt.summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R" & V4!="807F" & V4!="1050R" ), ]
arch.all$V4=factor(bgt.arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R"))

cyano.all <- bgt.summary[with(bgt.summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"  & V4!="807F" & V4!="1050R"), ]
cyano.all$V4=factor(bgt.cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

bact.all <- bgt.summary[with(bgt.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"  & V4!="807F" & V4!="1050R"), ]
bact.all$V4=factor(bgt.bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

euk.all <- summary[with(summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, all datasets")
print(mean(arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R")){
    sliced <- arch.all[with(arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, all datasets")
print(mean(bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- bact.all[with(bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}


print("CYANO summaries, all datasets")
print(mean(cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- cyano.all[with(cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, all datasets")
print(mean(euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- euk.all[with(euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, all datasets"
# [1] 36.90755
# [1] "341F"             "37.7311977715877"
# [1] "785R"            "35.390243902439"
# [1] "515Y"            "33.076512455516"
# [1] "806RB"            "35.8990825688073"
# [1] "926R"             "38.0965517241379"
# [1] "926wF"            "38.0862068965517"
# [1] "1392R"            "41.3566878980892"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "BACT summaries, all datasets"
# [1] 256.8651
# [1] "27F"              "62.8030431107354"
# [1] "338R"             "307.459016393443"
# [1] "341F"             "324.481147540984"
# [1] "785R"             "257.197703035275"
# [1] "515Y"             "273.999180327869"
# [1] "806RB"            "259.331967213115"
# [1] "926R"             "271.861133935908"
# [1] "926wF"            "270.998357963875"
# [1] "1392R"            "277.829508196721"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "CYANO summaries, all datasets"
# [1] 46.27692
# [1] "27F"              "26.2885496183206"
# ...

# %%
#TARA <3uM summaries
summary <- read.delim("/home/jesse/MG-primer-eval/Tara-lt3uM/TARA-lt3uM.compute-results.tsv", header=FALSE)

arch.all <- summary[with(summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

cyano.all <- summary[with(summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

bact.all <- summary[with(summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

euk.all <- summary[with(summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, Tara lt 3uM")
print(mean(arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R")){
    sliced <- arch.all[with(arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, Tara lt 3uM")
print(mean(bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- bact.all[with(bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}


print("CYANO summaries, Tara lt 3uM")
print(mean(cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- cyano.all[with(cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, Tara lt 3uM")
print(mean(euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- euk.all[with(euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, Tara lt 3uM"
# [1] 109.0583
# [1] "341F"             "139.062068965517"
# [1] "785R"             "92.7542213883677"
# [1] "515Y"            "131.30258302583"
# [1] "806RB"            "93.5131086142322"
# [1] "926R"             "89.8870673952641"
# [1] "926wF"            "90.0438756855576"
# [1] "1392R"            "129.909246575342"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "BACT summaries, Tara lt 3uM"
# [1] 1147.974
# [1] "27F"              "455.247630331754"
# [1] "338R"            "1299.0369955157"
# [1] "341F"             "1384.64804469274"
# [1] "785R"             "1051.36231884058"
# [1] "515Y"             "1045.38988764045"
# [1] "806RB"            "1079.18151447661"
# [1] "926R"             "1361.57477678571"
# [1] "926wF"            "1360.23772321429"
# [1] "1392R"            "1254.56035437431"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "CYANO summaries, Tara lt 3uM"
# [1] 141.6507
# [1] "27F"              "167.599206349206"
# ...

# %%
#Malaspina summaries
summary <- read.delim("/home/jesse/MG-primer-eval/Malaspina_Acinas_2019/Malaspina_Acinas_2019.compute-results.tsv", header=FALSE)

arch.all <- summary[with(summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

cyano.all <- summary[with(summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

bact.all <- summary[with(summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

euk.all <- summary[with(summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, Malaspina")
print(mean(arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R")){
    sliced <- arch.all[with(arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, Malaspina")
print(mean(bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- bact.all[with(bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}


print("CYANO summaries, Malaspina")
print(mean(cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- cyano.all[with(cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, Malaspina")
print(mean(euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- euk.all[with(euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, Malaspina"
# [1] 26.34286
# [1] "341F"  "38.65"
# [1] "785R"             "19.4897959183673"
# [1] "515Y"             "30.1929824561403"
# [1] "806RB"            "19.9795918367347"
# [1] "926R"             "22.9818181818182"
# [1] "926wF"            "22.9818181818182"
# [1] "1392R"            "27.3333333333333"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "BACT summaries, Malaspina"
# [1] 158.4094
# [1] "27F"              "41.6782608695652"
# [1] "338R"             "169.181034482759"
# [1] "341F"             "181.543103448276"
# [1] "785R"             "128.922413793103"
# [1] "515Y"             "163.051724137931"
# [1] "806RB"            "131.577586206897"
# [1] "926R"             "216.715517241379"
# [1] "926wF"            "216.525862068966"
# [1] "1392R"           "175.48275862069"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "CYANO summaries, Malaspina"
# [1] 20.59091
# [1] "27F"  "19.5"
# [1] "338R"  "20.75"
# [1] "341F" "21"
# [1] "785R" "NaN"
# ...

# %%
#MBARI summaries
summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622-MG/MBARI-bloom.compute-results.tsv", header=FALSE)

arch.all <- summary[with(summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

cyano.all <- summary[with(summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

bact.all <- summary[with(summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

euk.all <- summary[with(summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, MBARI")
print(mean(arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R")){
    sliced <- arch.all[with(arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, MBARI")
print(mean(bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- bact.all[with(bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}


print("CYANO summaries, MBARI")
print(mean(cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- cyano.all[with(cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, MBARI")
print(mean(euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- euk.all[with(euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, MBARI"
# [1] 25.65491
# [1] "341F"             "27.8955223880597"
# [1] "785R"             "26.2045454545455"
# [1] "515Y"             "27.4776119402985"
# [1] "806RB"           "26.906976744186"
# [1] "926R"             "22.0980392156863"
# [1] "926wF"            "22.0980392156863"
# [1] "1392R"           "26.041095890411"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "BACT summaries, MBARI"
# [1] 667.7209
# [1] "27F"              "177.553571428571"
# [1] "338R"             "643.505952380952"
# [1] "341F"             "706.130952380952"
# [1] "785R"             "746.958333333333"
# [1] "515Y"             "791.934523809524"
# [1] "806RB"            "759.833333333333"
# [1] "926R"             "692.178571428571"
# [1] "926wF"            "691.404761904762"
# [1] "1392R"            "799.988095238095"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "CYANO summaries, MBARI"
# [1] 52.37983
# [1] "27F"             "21.219512195122"
# [1] "338R"   "47.375"
# ...

# %%
#Dimensions summaries
summary <- read.delim("/home/jesse/MG-primer-eval/Dimensions-SPOT-Catalina/Dimension_SPOT_CAT.compute-results.MG.tsv", header=FALSE)

arch.all <- summary[with(summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

cyano.all <- summary[with(summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

bact.all <- summary[with(summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

euk.all <- summary[with(summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, Dimensions")
print(mean(arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R")){
    sliced <- arch.all[with(arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, Dimensions")
print(mean(bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- bact.all[with(bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}


print("CYANO summaries, Dimensions")
print(mean(cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- cyano.all[with(cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, Dimensions")
print(mean(euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- euk.all[with(euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, Dimensions"
# [1] 16.93478
# [1] "341F" "25"
# [1] "785R" "12.5"
# [1] "515Y"             "16.1111111111111"
# [1] "806RB" "12.2"
# [1] "926R" "13.4"
# [1] "926wF" "13.4"
# [1] "1392R" "18.9"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "BACT summaries, Dimensions"
# [1] 434.1875
# [1] "27F"     "117.375"
# [1] "338R"    "477.625"
# [1] "341F"    "534.125"
# [1] "785R"     "374.6875"
# [1] "515Y"    "406.875"
# [1] "806RB"   "384.375"
# [1] "926R"     "505.5625"
# [1] "926wF"  "503.25"
# [1] "1392R"    "603.8125"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "CYANO summaries, Dimensions"
# [1] 186.2263
# [1] "27F"              "62.2857142857143"
# [1] "338R"  "201.6"
# [1] "341F"             "214.866666666667"
# [1] "785R" "171"
# [1] "515Y"             "241.466666666667"
# [1] "806RB"    "175.8125"
# [1] "926R"             "205.066666666667"
# [1] "926wF" "234.5"
# [1] "1392R"            "159.666666666667"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# ...

# %%
#Saanich summaries
summary <- read.delim("/home/jesse/MG-primer-eval/Saanich_Inlet/Saanich_inlet.compute-results.tsv", header=FALSE)

arch.all <- summary[with(summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

cyano.all <- summary[with(summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

bact.all <- summary[with(summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

euk.all <- summary[with(summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, Saanich")
print(mean(arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R")){
    sliced <- arch.all[with(arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, Saanich")
print(mean(bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- bact.all[with(bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("CYANO summaries, Saanich")
print(mean(cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- cyano.all[with(cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, Saanich")
print(mean(euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- euk.all[with(euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, Saanich"
# [1] 96.78498
# [1] "341F"             "120.734939759036"
# [1] "785R"             "73.6344827586207"
# [1] "515Y"             "111.648648648649"
# [1] "806RB"            "75.5655172413793"
# [1] "926R"             "82.6510067114094"
# [1] "926wF"            "82.5369127516778"
# [1] "1392R"            "125.018518518519"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "BACT summaries, Saanich"
# [1] 662.6225
# [1] "27F"              "185.093023255814"
# [1] "338R"             "713.331395348837"
# [1] "341F"             "777.767441860465"
# [1] "785R"             "665.476744186047"
# [1] "515Y"            "665.66081871345"
# [1] "806RB"            "678.517441860465"
# [1] "926R"             "783.436046511628"
# [1] "926wF"            "782.331395348837"
# [1] "1392R"            "712.005813953488"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "CYANO summaries, Saanich"
# [1] 88.89286
# [1] "27F"              "60.1428571428571"
# [1] "338R" "79.6"
# ...

# %%
#Guaymas summaries
summary <- read.delim("/home/jesse/MG-primer-eval/Guaymas_Dombrowski_2018/Guaymas_sediments.compute-results.tsv", header=FALSE)

arch.all <- summary[with(summary, V3=="ARCH" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

cyano.all <- summary[with(summary, V3=="BACT-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

bact.all <- summary[with(summary, V3=="BACT-NON-CYANO" & V6>=10 & V5=="0-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R"))

euk.all <- summary[with(summary, V3=="EUK" & V5=="0-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

print("ARCH summaries, Guaymas")
print(mean(arch.all$V6))
for (primer in c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R")){
    sliced <- arch.all[with(arch.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("BACT summaries, Guaymas")
print(mean(bact.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- bact.all[with(bact.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("CYANO summaries, Guaymas")
print(mean(cyano.all$V6))
for (primer in c("27F","338R","341F","785R","515Y","806RB","926R","926wF","1392R","807F","1050R")){
    sliced <- cyano.all[with(cyano.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}

print("EUK summaries, Guaymas")
print(mean(euk.all$V6))
for (primer in c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R")){
    sliced <- euk.all[with(euk.all, V4==primer), ]
    averageLength <- mean(sliced$V6, na.rm=TRUE)
    print(c(primer, averageLength))   
}
# Out:
# [1] "ARCH summaries, Guaymas"
# [1] 1047.258
# [1] "341F"   "1405.5"
# [1] "785R"    "903.875"
# [1] "515Y"     "1281.625"
# [1] "806RB"   "934.125"
# [1] "926R"    "974.625"
# [1] "926wF"  "974.25"
# [1] "1392R" "1459"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "BACT summaries, Guaymas"
# [1] 3065.597
# [1] "27F"    "885.75"
# [1] "338R"   "3107.5"
# [1] "341F" "3338"
# [1] "785R"   "3330.5"
# [1] "515Y"    "3614.75"
# [1] "806RB"    "3365.125"
# [1] "926R"     "3118.125"
# [1] "926wF" "3116"
# [1] "1392R"    "3714.625"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "CYANO summaries, Guaymas"
# [1] 93.02778
# [1] "27F"  "76.5"
# [1] "338R" "123"
# [1] "341F"  "141.5"
# [1] "785R"             "71.4285714285714"
# [1] "515Y"             "115.666666666667"
# [1] "806RB"            "83.3333333333333"
# [1] "926R"   "110.25"
# [1] "926wF" "139.5"
# [1] "1392R" "53.5"
# [1] "807F" "NaN"
# [1] "1050R" "NaN"
# [1] "EUK summaries, Guaymas"
# [1] 433.6944
# [1] "515Y"    "447.125"
# ...

# %%
#Master figure for following datasets processed data (16S merged, and 18S merged fwd+rev)
#BioGEOTRACES, Malaspina, MBARI, Tara < 3uM
#"Worst Case", assuming primer misses are additive
library(boxplotdbl)
library(gridExtra)
library(ggplot2)
library(egg)
library(stringr)

all.summary <- read.delim("/home/jesse/MG-primer-eval/master-figure-workflow/BGT-Dimensions-Malaspina-MBARI-TARA.tsv", header=FALSE)
#eukuniv.all= all.summary[with(all.summary, V3=="18S" & V2=="V4-V5_UNIV" | V2 == "V5-V8_UNIV"), ]
all.summary$V5[all.summary$V2=="V4_EUK"] <- "V4 (V4F/V4RB)"
all.summary$V5[all.summary$V2=="V4-V5_UNIV"] <- "V4-V5 (515Y/926R)"
all.summary$V5[all.summary$V2=="V5-V8_UNIV"] <- "V5-V8 (926wF/1392R)"
all.summary$V5[all.summary$V2=="V9_EUK"] <- "V9 (1389F/1510R)"
all.summary$V5[all.summary$V2=="V1-V2_BACT"] <- "V1-V2 (27F/338R)"
all.summary$V5[all.summary$V2=="V3-V4_BACT"] <- "V3-V4 (341F/785R)"
all.summary$V5[all.summary$V2=="V4_PROK"] <- "V4 (515Y/806RB)"

prokuniv.all= all.summary[with(all.summary, V3=="16S" & V2=="V4-V5_UNIV" | V2 == "V5-V8_UNIV"), ]

eukonly.all <- all.summary[with(all.summary, V3=="18S"), ]# & V2!="V4-V5_UNIV" & V2 != "V5-V8_UNIV"), ]

p1 <- ggplot(eukonly.all, aes(x=V5, y=V4)) +
geom_boxplot(show.legend = FALSE) + labs(x="Primer pair", y="Fraction MG 18S rRNA matching primers") +
coord_flip() +
theme_bw() + theme(plot.title = element_text(hjust = 0.7), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.3)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(angle = 0, hjust = 0, size = rel(1.3)), strip.text = element_text(size = rel(1.2)),
                        axis.text.y = element_blank(), axis.title.y = element_blank(),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )

prokonly.all <- all.summary[with(all.summary, V3=="16S"), ]
p2 <- ggplot(prokonly.all, aes(x=V5, y=V4)) +
geom_boxplot(show.legend = FALSE) + labs(x="Primer pair", y="Fraction MG 16S rRNA matching primers") +
#scale_y_reverse() +
coord_flip() +
theme_bw() + theme(plot.title = element_text(hjust = 0.7), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.3)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(angle = 0, hjust = 0, size = rel(1.3)), strip.text = element_text(size = rel(1.2)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) ) #+
#scale_x_discrete(labels = function(x) str_wrap(x, width = 2))

#boxplotdou(prokonly.all[c(2,4)], eukonly.all[c(2,4)], xlim=c(0, 1), ylim=c(0, 1))

p <- ggarrange(p2, p1, ncol=2)
ggsave(file="./plots/BGT-Dimensions-Malaspina-MBARI-TARA.Fig1.pdf", plot=p, width=10, height=6)
# Out:
# plot without title

# %%
#Test overall figure, using MBARI and BGT data summarized
#0-mismatch data only, as output from normalization pipeline
#"Average Case", using normalization pipeline above
library(ggplot2)
library(stringr)
library(grid)

all.summary <- read.delim("/home/jesse/MG-primer-eval/BGT-Dimensions-Malaspina-MBARI-TARA.noMT.tsv", header=FALSE)

arch.all <- all.summary[with(all.summary, V3=="ARCH" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R"), ]
arch.all$V19=factor(arch.all$V19, levels=c("V4_PROK", "V4-V5_UNIV", "V5-V8_UNIV"))

arch.all$V22[arch.all$V19=="V4_PROK"] <- "Archaea"
arch.all$V22[arch.all$V19=="V4-V5_UNIV"] <- "Archaea"
arch.all$V22[arch.all$V19=="V5-V8_UNIV"] <- "Archaea"

arch.all$V23[arch.all$V19=="V4_PROK"] <- "PROK V4\n(515Y/806RB)"
arch.all$V23[arch.all$V19=="V4-V5_UNIV"] <- "UNIV2 V4-V5\n(515Y/926R)"
arch.all$V23[arch.all$V19=="V5-V8_UNIV"] <- "UNIV V5-V8\n(926wF/1392R)"

bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R"), ]
bact.all$V19=factor(bact.all$V19, levels=c("V1-V2_BACT", "V3-V4_BACT", "V4_PROK", "V4-V5_UNIV", "V5-V8_UNIV"))

bact.all$V22[bact.all$V19=="V1-V2_BACT"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V3-V4_BACT"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V4_PROK"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V4-V5_UNIV"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V5-V8_UNIV"] <- "Bacteria\n(non-photosynthetic)"

bact.all$V23[bact.all$V19=="V1-V2_BACT"] <- "BACT2 V1-V2\n(27F/338R)"
bact.all$V23[bact.all$V19=="V3-V4_BACT"] <- "BACT V3-V4\n(341F/785R)"
bact.all$V23[bact.all$V19=="V4_PROK"] <- "PROK V4\n(515Y/806RB)"
bact.all$V23[bact.all$V19=="V4-V5_UNIV"] <- "UNIV2 V4-V5\n(515Y/926R)"
bact.all$V23[bact.all$V19=="V5-V8_UNIV"] <- "UNIV V5-V8\n(926wF/1392R)"

cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R"), ]
cyano.all$V19=factor(cyano.all$V19, levels=c("V1-V2_BACT", "V3-V4_BACT", "V4_PROK", "V4-V5_UNIV", "V5-V8_UNIV"))

cyano.all$V22[cyano.all$V19=="V1-V2_BACT"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V3-V4_BACT"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V4_PROK"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V4-V5_UNIV"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V5-V8_UNIV"] <- "Cyanobacteria +\nPlastid 16S"

cyano.all$V23[cyano.all$V19=="V1-V2_BACT"] <- "BACT2 V1-V2\n(27F/338R)"
cyano.all$V23[cyano.all$V19=="V3-V4_BACT"] <- "BACT V3-V4\n(341F/785R)"
cyano.all$V23[cyano.all$V19=="V4_PROK"] <- "PROK V4\n(515Y/806RB)"
cyano.all$V23[cyano.all$V19=="V4-V5_UNIV"] <- "UNIV2 V4-V5\n(515Y/926R)"
cyano.all$V23[cyano.all$V19=="V5-V8_UNIV"] <- "UNIV V5-V8\n(926wF/1392R)"

euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R" & V4!="807F" & V4!="1050R" & V4!="V4R"), ]
euk.all$V19=factor(euk.all$V19, levels=c("V4_EUK", "V4-V5_UNIV", "V5-V8_UNIV", "V9_EUK"))

euk.all$V22[euk.all$V19=="V4_EUK"] <- "Eukarya (18S)"
euk.all$V22[euk.all$V19=="V4-V5_UNIV"] <- "Eukarya (18S)"
euk.all$V22[euk.all$V19=="V5-V8_UNIV"] <- "Eukarya (18S)"
euk.all$V22[euk.all$V19=="V9_EUK"] <- "Eukarya (18S)"

euk.all$V23[euk.all$V19=="V4_EUK"] <- "EUK2 V4\n(V4F/V4RB;\n518F/770R)"
euk.all$V23[euk.all$V19=="V4-V5_UNIV"] <- "UNIV2 V4-V5\n(515Y/926R)"
euk.all$V23[euk.all$V19=="V5-V8_UNIV"] <- "UNIV V5-V8\n(926wF/1392R)"
euk.all$V23[euk.all$V19=="V9_EUK"] <- "EUK V9\n(1389F/1510R)"

#per Jed's request
all.ssu.summary <- read.delim("/home/jesse/MG-primer-eval/master-figure-workflow/BGT-Dimensions-Malaspina-MBARI-TARA-allSSU.tsv", header=FALSE)
all.ssu.summary$V22 <-"All SSU rRNA\nTargeted by Primers"
all.ssu.summary$V23[all.ssu.summary$V2=="V1-V2_BACT"] <- "BACT2 V1-V2\n(27F/338R)"
all.ssu.summary$V23[all.ssu.summary$V2=="V3-V4_BACT"] <- "BACT V3-V4\n(341F/785R)"
all.ssu.summary$V23[all.ssu.summary$V2=="V4_PROK"] <- "PROK V4\n(515Y/806RB)"
all.ssu.summary$V23[all.ssu.summary$V2=="V4-V5_UNIV"] <- "UNIV2 V4-V5\n(515Y/926R)"
all.ssu.summary$V23[all.ssu.summary$V2=="V5-V8_UNIV"] <- "UNIV V5-V8\n(926wF/1392R)"
all.ssu.summary$V23[all.ssu.summary$V2=="V4_EUK"] <- "EUK2 V4\n(V4F/V4RB;\n518F/770R)"
all.ssu.summary$V23[all.ssu.summary$V2=="V9_EUK"] <- "EUK V9\n(1389F/1510R)"
all.ssu.summary$V20 <- all.ssu.summary$V4

dat <- rbind(arch.all[c("V20","V22","V23")], bact.all[c("V20","V22","V23")], cyano.all[c("V20","V22","V23")], euk.all[c("V20","V22","V23")], all.ssu.summary[c("V20","V22","V23")])

p <- ggplot(subset(dat, !is.na(V23)), aes(x=V23, y=V20)) +
geom_violin(show.legend = FALSE, scale="width") + labs(x="Primer pair", y="Fraction metagenomic SSU rRNA matching primer pairs\n(BioGEOTRACES/HOT/BATS + Malaspina + MBARI + SPOT + Tara)") +
facet_grid(. ~ V22)
#p + geom_dotplot(binaxis='y', stackdir='center', dotsize=0.1)
#p<-p + geom_jitter(shape=16, position=position_jitter(0.2),size=0.1)
p<-p+scale_y_continuous(breaks=seq(0,1,by=0.2)) + coord_flip()
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.7), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.spacing = unit(1.4, "lines"),
                        #panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        #panel.grid.major.x = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.y = element_blank(), 
                        axis.title = element_text(size = rel(2.5)), #axis.line = element_line(colour = "black"),
                        axis.text.x = element_text(angle = 0, size = rel(2.5), hjust=0.5), strip.text = element_text(size = rel(1.95)),
                        axis.text.y = element_text(angle = 0, size = rel(2.5), hjust=0.5),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p<-p + geom_boxplot(width=0.1, outlier.size=1)
ggsave(file="./plots/BGT-Dimensions-Malaspina-MBARI-TARA.Fig2.pdf", plot=p, width=18, height=11)
p
# Out:
# plot without title

# %%
#Archaeal stats
EMP.arch.all = arch.all[arch.all$V19 == "V4_PROK", ]
EMP.arch.median = median(EMP.arch.all$V20, na.rm=TRUE)
parada.arch.all = arch.all[arch.all$V19 == "V4-V5_UNIV", ]
parada.arch.median = median(parada.arch.all$V20, na.rm=TRUE)
v5v8.arch.all = arch.all[arch.all$V19 == "V5-V8_UNIV", ]
v5v8.arch.median = median(v5v8.arch.all$V20, na.rm=TRUE)
print("Archaea")
print(EMP.arch.median)
print(parada.arch.median)
print(v5v8.arch.median)

#Bacterial stats
v1v2.bact.all = bact.all[bact.all$V19 == "V1-V2_BACT", ]
v1v2.bact.median = median(v1v2.bact.all$V20, na.rm=TRUE)
f27.bact.median = median(v1v2.bact.all$V9, na.rm=TRUE)
r338.bact.median = median(v1v2.bact.all$V18, na.rm=TRUE)
v3v4.bact.all = bact.all[bact.all$V19 == "V3-V4_BACT", ]
v3v4.bact.median = median(v3v4.bact.all$V20, na.rm=TRUE)
f341.bact.median = median(v3v4.bact.all$V9, na.rm=TRUE)
r785.bact.median = median(v3v4.bact.all$V18, na.rm=TRUE)
EMP.bact.all = bact.all[bact.all$V19 == "V4_PROK", ]
EMP.bact.median = median(EMP.bact.all$V20, na.rm=TRUE)
parada.bact.all = bact.all[bact.all$V19 == "V4-V5_UNIV", ]
parada.bact.median = median(parada.bact.all$V20, na.rm=TRUE)
v5v8.bact.all = bact.all[bact.all$V19 == "V5-V8_UNIV", ]
v5v8.bact.median = median(v5v8.bact.all$V20, na.rm=TRUE)
f926.bact.median = median(v5v8.bact.all$V9, na.rm=TRUE)
r1392.bact.median = median(v5v8.bact.all$V18, na.rm=TRUE)
print("Bacteria non-cyano")
print("v1v2")
print(v1v2.bact.median)
print("27F")
print(f27.bact.median)
print("338R")
print(r338.bact.median)
print("v3v4")
print(v3v4.bact.median)
print("341F")
print(f341.bact.median)
print("785R")
print(r785.bact.median)
print("EMP")
print(EMP.bact.median)
print("parada")
print(parada.bact.median)
print("v5v8")
print(v5v8.bact.median)
print("926wF")
print(f926.bact.median)
print("1392R")
print(r1392.bact.median)


#Cyanobacterial stats
v1v2.cyano.all = cyano.all[cyano.all$V19 == "V1-V2_BACT", ]
v1v2.cyano.median = median(v1v2.cyano.all$V20, na.rm=TRUE)
f27.cyano.median = median(v1v2.cyano.all$V9, na.rm=TRUE)
r338.cyano.median = median(v1v2.cyano.all$V18, na.rm=TRUE)
v3v4.cyano.all = cyano.all[cyano.all$V19 == "V3-V4_BACT", ]
v3v4.cyano.median = median(v3v4.cyano.all$V20, na.rm=TRUE)
f341.cyano.median = median(v3v4.cyano.all$V9, na.rm=TRUE)
r785.cyano.median = median(v3v4.cyano.all$V18, na.rm=TRUE)
EMP.cyano.all = cyano.all[cyano.all$V19 == "V4_PROK", ]
EMP.cyano.median = median(EMP.cyano.all$V20, na.rm=TRUE)
parada.cyano.all = cyano.all[cyano.all$V19 == "V4-V5_UNIV", ]
parada.cyano.median = median(parada.cyano.all$V20, na.rm=TRUE)
v5v8.cyano.all = cyano.all[cyano.all$V19 == "V5-V8_UNIV", ]
v5v8.cyano.median = median(v5v8.cyano.all$V20, na.rm=TRUE)
f926.cyano.median = median(v5v8.cyano.all$V9, na.rm=TRUE)
r1392.cyano.median = median(v5v8.cyano.all$V18, na.rm=TRUE)
print("Bact-cyano")
print("v1v2")
print(v1v2.cyano.median)
print("v3v4")
print(v3v4.cyano.median)
print("EMP")
print(EMP.cyano.median)
print("parada")
print(parada.cyano.median)
print("v5v8")
print(v5v8.cyano.median)



v4fv4rb.euk.all = euk.all[euk.all$V19 == "V4_EUK", ]
v4fv4rb.euk.median = median(v4fv4rb.euk.all$V20, na.rm=TRUE)
parada.euk.all = euk.all[euk.all$V19 == "V4-V5_UNIV", ]
parada.euk.median = median(parada.euk.all$V20, na.rm=TRUE)
v5v8.euk.all = euk.all[euk.all$V19 == "V5-V8_UNIV", ]
v5v8.euk.median = median(v5v8.euk.all$V20, na.rm=TRUE)
v9.euk.all = euk.all[euk.all$V19 == "V9_EUK", ]
v9.euk.median = median(v9.euk.all$V20, na.rm=TRUE)

print("euk")
print("parada")
print(parada.euk.median)
print("v4f")
print(v4fv4rb.euk.median)
print("v5v8")
print(v5v8.euk.median)
print("v9")
print(v9.euk.median)
# Out:
# [1] "Archaea"
# [1] 0.9957757
# [1] 0.9823859
# [1] 0.951852
# [1] "Bacteria non-cyano"
# [1] "v1v2"
# [1] 0.887831
# [1] "27F"
# [1] 0.9681
# [1] "338R"
# [1] 0.9126
# [1] "v3v4"
# [1] 0.5251239
# [1] "341F"
# [1] 0.8872
# [1] "785R"
# [1] 0.624
# [1] "EMP"
# [1] 0.9546462
# [1] "parada"
# [1] 0.9605785
# [1] "v5v8"
# [1] 0.8687317
# [1] "926wF"
# [1] 0.9155
# [1] "1392R"
# [1] 0.9431
# [1] "Bact-cyano"
# [1] "v1v2"
# [1] 0.8256893
# [1] "v3v4"
# [1] 0.7017454
# [1] "EMP"
# [1] 0.8809843
# [1] "parada"
# [1] 0.9915162
# [1] "v5v8"
# [1] 0.7144338
# [1] "euk"
# [1] "parada"
# [1] 0.8833947
# [1] "v4f"
# [1] 0.8221511
# [1] "v5v8"
# [1] 0.7916763
# [1] "v9"
# [1] 0.7322137

# %%
#Overall figure, using 2 unusual environments (Saanich, Guaymas)
#0-mismatch data only, as output from normalization pipeline
#"Average Case", using normalization pipeline above
library(ggplot2)
library(stringr)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Saanich-Guaymas-MG-normalized-output.tsv", header=FALSE)

arch.all <- all.summary[with(all.summary, V3=="ARCH" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R"), ]
arch.all$V19=factor(arch.all$V19, levels=c("V4_PROK", "V4-V5_UNIV", "V5-V8_UNIV"))

arch.all$V22[arch.all$V19=="V4_PROK"] <- "Archaea"
arch.all$V22[arch.all$V19=="V4-V5_UNIV"] <- "Archaea"
arch.all$V22[arch.all$V19=="V5-V8_UNIV"] <- "Archaea"

arch.all$V23[arch.all$V19=="V4_PROK"] <- "V4\n(515Y/806RB)"
arch.all$V23[arch.all$V19=="V4-V5_UNIV"] <- "V4-V5\n(515Y/926R)"
arch.all$V23[arch.all$V19=="V5-V8_UNIV"] <- "V5-V8\n(926wF/1392R)"

bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R"), ]
bact.all$V19=factor(bact.all$V19, levels=c("V1-V2_BACT", "V3-V4_BACT", "V4_PROK", "V4-V5_UNIV", "V5-V8_UNIV"))

bact.all$V22[bact.all$V19=="V1-V2_BACT"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V3-V4_BACT"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V4_PROK"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V4-V5_UNIV"] <- "Bacteria\n(non-photosynthetic)"
bact.all$V22[bact.all$V19=="V5-V8_UNIV"] <- "Bacteria\n(non-photosynthetic)"

bact.all$V23[bact.all$V19=="V1-V2_BACT"] <- "V1-V2\n(27F/338R)"
bact.all$V23[bact.all$V19=="V3-V4_BACT"] <- "V3-V4\n(341F/785R)"
bact.all$V23[bact.all$V19=="V4_PROK"] <- "V4\n(515Y/806RB)"
bact.all$V23[bact.all$V19=="V4-V5_UNIV"] <- "V4-V5\n(515Y/926R)"
bact.all$V23[bact.all$V19=="V5-V8_UNIV"] <- "V5-V8\n(926wF/1392R)"

cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R"), ]
cyano.all$V19=factor(cyano.all$V19, levels=c("V1-V2_BACT", "V3-V4_BACT", "V4_PROK", "V4-V5_UNIV", "V5-V8_UNIV"))

cyano.all$V22[cyano.all$V19=="V1-V2_BACT"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V3-V4_BACT"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V4_PROK"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V4-V5_UNIV"] <- "Cyanobacteria +\nPlastid 16S"
cyano.all$V22[cyano.all$V19=="V5-V8_UNIV"] <- "Cyanobacteria +\nPlastid 16S"

cyano.all$V23[cyano.all$V19=="V1-V2_BACT"] <- "V1-V2\n(27F/338R)"
cyano.all$V23[cyano.all$V19=="V3-V4_BACT"] <- "V3-V4\n(341F/785R)"
cyano.all$V23[cyano.all$V19=="V4_PROK"] <- "V4\n(515Y/806RB)"
cyano.all$V23[cyano.all$V19=="V4-V5_UNIV"] <- "V4-V5\n(515Y/926R)"
cyano.all$V23[cyano.all$V19=="V5-V8_UNIV"] <- "V5-V8\n(926wF/1392R)"

euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R" & V4!="807F" & V4!="1050R" & V4!="V4R"), ]
euk.all$V19=factor(euk.all$V19, levels=c("V4_EUK", "V4-V5_UNIV", "V5-V8_UNIV", "V9_EUK"))

euk.all$V22[euk.all$V19=="V4_EUK"] <- "Eukarya (18S)"
euk.all$V22[euk.all$V19=="V4-V5_UNIV"] <- "Eukarya (18S)"
euk.all$V22[euk.all$V19=="V5-V8_UNIV"] <- "Eukarya (18S)"
euk.all$V22[euk.all$V19=="V9_EUK"] <- "Eukarya (18S)"

euk.all$V23[euk.all$V19=="V4_EUK"] <- "V4\n(V4F/V4RB)"
euk.all$V23[euk.all$V19=="V4-V5_UNIV"] <- "V4-V5\n(515Y/926R)"
euk.all$V23[euk.all$V19=="V5-V8_UNIV"] <- "V5-V8\n(926wF/1392R)"
euk.all$V23[euk.all$V19=="V9_EUK"] <- "V9\n(1389F/1510R)"

dat <- rbind(arch.all, bact.all, cyano.all, euk.all)

p <- ggplot(subset(dat, !is.na(V23)), aes(x=V23, y=V20)) +
geom_violin(show.legend = FALSE) + labs(x="Primer pair", y="Fraction metagenomic SSU rRNA matching primer pairs\n(Saanich Inlet Redoxcline and Guaymas Hydrothermal Sediments)") +
facet_grid(. ~ V22)
#p + geom_dotplot(binaxis='y', stackdir='center', dotsize=0.1)
#p<-p + geom_jitter(shape=16, position=position_jitter(0.2),size=0.1)
p<-p+scale_y_continuous(breaks=seq(0,1,by=0.1)) + coord_flip()
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.7), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        #panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.major.x = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.y = element_blank(), 
                        axis.title = element_text(size = rel(2.5)), #axis.line = element_line(colour = "black"),
                        axis.text.x = element_text(angle = 90, size = rel(2.5), hjust=0.0), strip.text = element_text(size = rel(1.95)),
                        axis.text.y = element_text(angle = 0, size = rel(2.5), hjust=0.5),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p<-p + geom_boxplot(width=0.1, outlier.size=1)
ggsave(file="./plots/Saanich-Guaymas.FigX.pdf", plot=p, width=18, height=11)
p
# Out:
# plot without title

# %%
#Overall "best" primers, oxic seawater
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/dataset-summaries/overall-plots/200329_oxic_SW_incomplete.tsv", header=FALSE)
cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V6>=10 & V5!="6-mismatch" & V5!="2-mismatch" & V5!="1-mismatch" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="785R" & V4!="926wF" & V4!="1392R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("515Y","806RB","926R"))

cyano.all$V10[cyano.all$V4=="515Y"] <- "Cyanobacteria + Plastids"
cyano.all$V10[cyano.all$V4=="806RB"] <- "Cyanobacteria + Plastids"
cyano.all$V10[cyano.all$V4=="926R"] <- "Cyanobacteria + Plastids"

arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="1389F" & V4!="27F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="807F" & V4!="1050R" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="785R" & V4!="926wF" & V4!="1392R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("515Y","806RB","926R"))

arch.all$V10[arch.all$V4=="515Y"] <- "Archaea"
arch.all$V10[arch.all$V4=="806RB"] <- "Archaea"
arch.all$V10[arch.all$V4=="926R"] <- "Archaea"

bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"& V4!="807F" & V4!="1050R" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="785R" & V4!="926wF" & V4!="1392R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("515Y","806RB","926R"))

bact.all$V10[bact.all$V4=="515Y"] <- "Bacteria (No Cyano/plastid)"
bact.all$V10[bact.all$V4=="806RB"] <- "Bacteria (No Cyano/plastid)"
bact.all$V10[bact.all$V4=="926R"] <- "Bacteria (No Cyano/plastid)"

euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R" & V4!="807F" & V4!="1050R" & V4!="V4R" & V4!="926wF" & V4!="1392R" & V4!="1389F" & V4!="1510R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4RB"))

euk.all$V10[euk.all$V4=="515Y"] <- "Eukarya"
euk.all$V10[euk.all$V4=="926R"] <- "Eukarya"

euk.all$V10[euk.all$V4=="V4F"] <- "Eukarya"
euk.all$V10[euk.all$V4=="V4RB"] <- "Eukarya"

dat <- rbind(arch.all, bact.all, cyano.all, euk.all)

p <- ggplot(dat, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot(show.legend = FALSE) + labs(x="Primer", y="Coverage of BiHOBA/MBARI/MSPINA/SPOT/TARAlt3um MG SSU rRNA", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.3)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.2)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Overall-best-primers-MG-oxic-SW.pdf", plot=p, width=10, height=8)
p
# Out:
# Warning message:
# “Removed 54 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 54 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#Overall cyano/plastid
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/dataset-summaries/overall-plots/200329_oxic_SW_incomplete.tsv", header=FALSE)
cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V6>=10 & V5!="6-mismatch" & V5!="2-mismatch" & V5!="1-mismatch" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R" & V4!="807F" & V4!="1050R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

cyano.all$V10[cyano.all$V4=="515Y"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="806RB"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="926R"] <- "V4 / V4-V5"

cyano.all$V10[cyano.all$V4=="27F"] <- "V1-V2"
cyano.all$V10[cyano.all$V4=="338R"] <- "V1-V2"

cyano.all$V10[cyano.all$V4=="341F"] <- "V3-V4"
cyano.all$V10[cyano.all$V4=="785R"] <- "V3-V4"

cyano.all$V10[cyano.all$V4=="926wF"] <- "V6-V8"
cyano.all$V10[cyano.all$V4=="1392R"] <- "V6-V8"

cyano.all$V10[cyano.all$V4=="1389F"] <- "V9"
cyano.all$V10[cyano.all$V4=="1510R"] <- "V9"

p <- ggplot(cyano.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot(show.legend = FALSE) + labs(x="Primer", y="Coverage of BiHOBA/MBARI/MSPINA/SPOT/TARAlt3um MG SSU rRNA (Cyanobacteria + Plastids)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.1)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Overall-BACT-CYANO-MG.pdf", plot=p, width=10, height=8)
p
# Out:
# plot without title

# %%
#MBARI ARCH MG
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/dataset-summaries/overall-plots/200329_oxic_SW_incomplete.tsv", header=FALSE)
arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="1389F" & V4!="27F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="807F" & V4!="1050R"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

arch.all$V10[arch.all$V4=="515Y"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="806RB"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926R"] <- "V4 / V4-V5"

#arch.all$V10[arch.all$V4=="27F"] <- "V1-V2"
#arch.all$V10[arch.all$V4=="338R"] <- "V1-V2"

arch.all$V10[arch.all$V4=="341F"] <- "V3-V4"
arch.all$V10[arch.all$V4=="785R"] <- "V3-V4"

arch.all$V10[arch.all$V4=="926wF"] <- "V6-V8"
arch.all$V10[arch.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(arch.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot(show.legend = FALSE) + labs(x="Primer", y="Coverage of BiHOBA/MBARI/MSPINA/SPOT/TARAlt3um MG SSU rRNA (Archaea)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.2)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Overall-ARCH-MG.pdf", width=10, height=8)
p
# Out:
# plot without title

# %%
#Overall plots for BACT-NON-CYANO, all primers compared

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/dataset-summaries/overall-plots/200329_oxic_SW_incomplete.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"& V4!="807F" & V4!="1050R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot(show.legend = FALSE) + labs(x="Primer", y="Coverage of BiHOBA/MBARI/MSPINA/SPOT/TARAlt3um MG SSU rRNA (Bacteria)") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.2)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/Overall-BACT-NON-CYANO.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#Overall plots for EUKs, all primers compared
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/dataset-summaries/overall-plots/200329_oxic_SW_incomplete.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="1-mismatch" & V5!="2-mismatch" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R" & V4!="807F" & V4!="1050R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot(show.legend = FALSE) + labs(x="Primer", y="Coverage of BiHOBA/MBARI/MSPINA/SPOT/TARAlt3um MG SSU rRNA (Eukaryotes)") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.2)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Overall-EUK.pdf", plot=p, width=11, height=8)
p
# Out:
# Warning message:
# “Removed 195 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 195 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#Saanich inlet EUK
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Saanich_Inlet/compute-workflow-intermediate/200304_Saanich_complete_MG.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Saanich Inlet MG SSU rRNA (Eukaryotes)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Saanich-EUK.pdf", plot=p, width=11, height=8)
p
# Out:
# Warning message:
# “Removed 705 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 705 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#MBARI bloom EUK MT
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622/compute-workflow-intermediate/200327_MBARI_complete_MT.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of MBARI bloom MT SSU rRNA (Eukaryotes)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/MBARI-EUK-MT.pdf", plot=p, width=11, height=8)
p
# Out:
# Warning message:
# “Removed 114 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 114 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#MBARI bloom EUK
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622/compute-workflow-intermediate/200208_MBARI_complete_MG.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of MBARI bloom MG SSU rRNA (Eukaryotes)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/MBARI-EUK.pdf", plot=p, width=11, height=8)
p
# Out:
# plot without title

# %%
#Dimensions EUK MT
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Dimensions-SPOT-Catalina/compute-workflow-intermediate/200327_complete_MT.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Dimensions MT SSU rRNA (Eukaryotes)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Dimensions-EUK-MT.pdf", plot=p, width=11, height=8)
p
# Out:
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#Dimensions EUK MG
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Dimensions-SPOT-Catalina/compute-workflow-intermediate/200327_complete_MG.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Dimensions MG SSU rRNA (Eukaryotes)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Dimensions-EUK.pdf", plot=p, width=11, height=8)
p
# Out:
# plot without title

# %%
#Malaspina EUK
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Malaspina_Acinas_2019/compute-workflow-intermediate/200123_summary.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="6-mismatch" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","926wF","1392R","1389F","1510R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of bioGEOTRACES MG SSU rRNA (Eukaryotes)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Malaspina-EUK.pdf", plot=p, width=11, height=8)
p
# Out:
# Warning message:
# “Removed 348 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 348 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#bioGEOTRACES EUK
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/bioGEOTRACES/compute-workflow-intermediate/200808_incomplete.tsv", header=FALSE)
euk.all <- all.summary[with(all.summary, V3=="EUK" & V5!="6-mismatch" & V4!="V4R" & V4!="27F" & V4!="338R" & V4!="341F" & V4!="806RB" & V4!="785R" & V4!="807F" & V4!="1050R"), ]
euk.all$V4=factor(euk.all$V4, levels=c("515Y","926R","V4F","V4R","V4RB","F566Euk","R1200Euk","926wF","1392R","1389F","1510R","515Yp","926Rp"))#, "807F", "1050R"))

euk.all$V10[euk.all$V4=="515Y"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926R"] <- "V4-V5"

euk.all$V10[euk.all$V4=="515Yp"] <- "V4-V5"
euk.all$V10[euk.all$V4=="926Rp"] <- "V4-V5"

euk.all$V10[euk.all$V4=="F566Euk"] <- "V4-V5_Illinois"
euk.all$V10[euk.all$V4=="R1200Euk"] <- "V4-V5_Illinois"

euk.all$V10[euk.all$V4=="V4F"] <- "V4"
#euk.all$V10[euk.all$V4=="V4R"] <- "V4"
euk.all$V10[euk.all$V4=="V4RB"] <- "V4"

#euk.all$V10[euk.all$V4=="807F"] <- "V5-V6"
#euk.all$V10[euk.all$V4=="1050R"] <- "V5-V6"

euk.all$V10[euk.all$V4=="926wF"] <- "V6-V8"
euk.all$V10[euk.all$V4=="1392R"] <- "V6-V8"

euk.all$V10[euk.all$V4=="1389F"] <- "V9"
euk.all$V10[euk.all$V4=="1510R"] <- "V9"


p <- ggplot(euk.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of bioGEOTRACES MG SSU rRNA (Eukaryotes)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text.y = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        axis.text.x = element_text(size = rel(1.3), angle=90),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/bioGEOTRACES-EUK-illinois.pdf", plot=p, width=13, height=8)
p
# Out:
# Warning message:
# “Removed 162 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 162 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
#GORG BACT-NON-CYANO

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/GORG-16S/compute-workflow-intermediate/200327_complete_GORG.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V2=="BACT-NON-CYANO" & V5>=10 & V4!="6-mismatch" & V3!="V4F" & V3!="1389F" & V3!="1510R" & V3!="V4RB" & V3!="V4R"), ]
bact.all$V3=factor(bact.all$V3, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))


bact.all$V9[bact.all$V3=="515Y"] <- "V4 / V4-V5"
bact.all$V9[bact.all$V3=="806RB"] <- "V4 / V4-V5"
bact.all$V9[bact.all$V3=="926R"] <- "V4 / V4-V5"

bact.all$V9[bact.all$V3=="27F"] <- "V1-V2"
bact.all$V9[bact.all$V3=="338R"] <- "V1-V2"

bact.all$V9[bact.all$V3=="341F"] <- "V3-V4"
bact.all$V9[bact.all$V3=="785R"] <- "V3-V4"

bact.all$V9[bact.all$V3=="926wF"] <- "V6-V8"
bact.all$V9[bact.all$V3=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V3, y=V8, fill=V4)) +
geom_boxplot() + labs(x="Primer", y="Coverage of GORG SAG MG SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V9, scales="free")
p
#p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
#p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
#                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
#                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
#                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
#                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
#                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
#                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
#p
#ggsave(file="./plots/GORG-BACT-NON-CYANO.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#Saanich BACT-NON-CYANO

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Saanich_Inlet/compute-workflow-intermediate/200304_Saanich_complete_MG.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))


bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Saanich MG SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/Saanich-BACT-NON-CYANO.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#MBARI bloom bact MT

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622/compute-workflow-intermediate/200327_MBARI_complete_MT.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))


bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of MBARI bloom MT SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/MBARI-BACT-NON-CYANO-MT.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#MBARI bloom bact

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622/compute-workflow-intermediate/200208_MBARI_complete_MG.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))


bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of MBARI bloom MG SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/MBARI-BACT-NON-CYANO.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#Dimensions bact MT

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Dimensions-SPOT-Catalina/compute-workflow-intermediate/200327_complete_MT.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))


bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Dimensions MT SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/Dimensions-BACT-NON-CYANO-MT.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#Dimensions bact

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Dimensions-SPOT-Catalina/compute-workflow-intermediate/200327_complete_MG.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))


bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Dimensions MG SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/Dimensions-BACT-NON-CYANO.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#Malaspina bact

library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Malaspina_Acinas_2019/compute-workflow-intermediate/200123_summary.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))


bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Malaspina MG SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/Malaspina-BACT-NON-CYANO.pdf", plot=p, width=11, height=8)
# Out:
# plot without title

# %%
#BioGEOTRACES
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/bioGEOTRACES/compute-workflow-intermediate/200808_incomplete.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R","515Yp","926Rp"))

bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="515Yp"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926Rp"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="807F"] <- "V5-V6"
bact.all$V10[bact.all$V4=="1050R"] <- "V5-V6"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

#bact.all$V10[bact.all$V4=="1389F"] <- "V9"
#bact.all$V10[bact.all$V4=="1510R"] <- "V9"
#p <- ggplot(subset(dat, !is.na(V23)), aes(x=V23, y=V20)) +
p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of bioGEOTRACES MG SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text.y = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        axis.text.x = element_text(size = rel(1.3), angle=90),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/bioGEOTRACES-BACT-NON-CYANO.pdf", plot=p, width=12, height=8)
# Out:
# plot without title

# %%
#MBARI cyano/plastid
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622/compute-workflow-intermediate/200327_MBARI_complete_MT.tsv", header=FALSE)
cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

cyano.all$V10[cyano.all$V4=="515Y"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="806RB"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="926R"] <- "V4 / V4-V5"

cyano.all$V10[cyano.all$V4=="27F"] <- "V1-V2"
cyano.all$V10[cyano.all$V4=="338R"] <- "V1-V2"

cyano.all$V10[cyano.all$V4=="341F"] <- "V3-V4"
cyano.all$V10[cyano.all$V4=="785R"] <- "V3-V4"

cyano.all$V10[cyano.all$V4=="926wF"] <- "V6-V8"
cyano.all$V10[cyano.all$V4=="1392R"] <- "V6-V8"

cyano.all$V10[cyano.all$V4=="1389F"] <- "V9"
cyano.all$V10[cyano.all$V4=="1510R"] <- "V9"

p <- ggplot(cyano.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of MBARI bloom MT SSU rRNA (Cyanobacteria + Plastids)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/MBARI-MT-BACT-CYANO.pdf", plot=p, width=10, height=8)
p
# Out:
# plot without title

# %%
#Malaspina cyano/plastid
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Malaspina_Acinas_2019/compute-workflow-intermediate/200123_summary.tsv", header=FALSE)
cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R"))

cyano.all$V10[cyano.all$V4=="515Y"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="806RB"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="926R"] <- "V4 / V4-V5"

cyano.all$V10[cyano.all$V4=="27F"] <- "V1-V2"
cyano.all$V10[cyano.all$V4=="338R"] <- "V1-V2"

cyano.all$V10[cyano.all$V4=="341F"] <- "V3-V4"
cyano.all$V10[cyano.all$V4=="785R"] <- "V3-V4"

cyano.all$V10[cyano.all$V4=="926wF"] <- "V6-V8"
cyano.all$V10[cyano.all$V4=="1392R"] <- "V6-V8"

cyano.all$V10[cyano.all$V4=="1389F"] <- "V9"
cyano.all$V10[cyano.all$V4=="1510R"] <- "V9"

p <- ggplot(cyano.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of bioGEOTRACES MG SSU rRNA (Cyanobacteria + Plastids)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Malaspina-BACT-CYANO.pdf", plot=p, width=10, height=8)
p
# Out:
# plot without title

# %%
#BioGEOTRACES
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/bioGEOTRACES/compute-workflow-intermediate/200808_incomplete.tsv", header=FALSE)
cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="V4R" & V4!="V4RB" & V4!="1389F" & V4!="1510R"), ]
cyano.all$V4=factor(cyano.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R","515Yp","926Rp"))

cyano.all$V10[cyano.all$V4=="515Y"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="806RB"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="926R"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="515Yp"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="926Rp"] <- "V4 / V4-V5"

cyano.all$V10[cyano.all$V4=="27F"] <- "V1-V2"
cyano.all$V10[cyano.all$V4=="338R"] <- "V1-V2"

cyano.all$V10[cyano.all$V4=="341F"] <- "V3-V4"
cyano.all$V10[cyano.all$V4=="785R"] <- "V3-V4"

cyano.all$V10[cyano.all$V4=="807F"] <- "V5-V6"
cyano.all$V10[cyano.all$V4=="1050R"] <- "V5-V6"

cyano.all$V10[cyano.all$V4=="926wF"] <- "V6-V8"
cyano.all$V10[cyano.all$V4=="1392R"] <- "V6-V8"

cyano.all$V10[cyano.all$V4=="1389F"] <- "V9"
cyano.all$V10[cyano.all$V4=="1510R"] <- "V9"

p <- ggplot(cyano.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of bioGEOTRACES MG SSU rRNA (Cyanobacteria + Plastids)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text.y = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        axis.text.x = element_text(size = rel(1.3), angle=90),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/bioGEOTRACES-BACT-CYANO.pdf", plot=p, width=12, height=8)
p
# Out:
# plot without title

# %%
#MBARI ARCH MG
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622/compute-workflow-intermediate/200208_MBARI_complete_MG.tsv", header=FALSE)
arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="6-mismatch" & V4!="1389F" & V4!="27F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

arch.all$V10[arch.all$V4=="515Y"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="806RB"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926R"] <- "V4 / V4-V5"

#arch.all$V10[arch.all$V4=="27F"] <- "V1-V2"
#arch.all$V10[arch.all$V4=="338R"] <- "V1-V2"

arch.all$V10[arch.all$V4=="341F"] <- "V3-V4"
arch.all$V10[arch.all$V4=="785R"] <- "V3-V4"

arch.all$V10[arch.all$V4=="926wF"] <- "V6-V8"
arch.all$V10[arch.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(arch.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of MBARI MG SSU rRNA (Archaea)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/MBARI-ARCH-MG.pdf", width=10, height=8)
p
# Out:
# plot without title

# %%
#MBARI ARCH MT
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/MBARI_bloom_Nowinski_2019_PRJNA533622/compute-workflow-intermediate/200327_MBARI_complete_MT.tsv", header=FALSE)
arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="6-mismatch" & V4!="1389F" & V4!="27F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

arch.all$V10[arch.all$V4=="515Y"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="806RB"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926R"] <- "V4 / V4-V5"

#arch.all$V10[arch.all$V4=="27F"] <- "V1-V2"
#arch.all$V10[arch.all$V4=="338R"] <- "V1-V2"

arch.all$V10[arch.all$V4=="341F"] <- "V3-V4"
arch.all$V10[arch.all$V4=="785R"] <- "V3-V4"

arch.all$V10[arch.all$V4=="926wF"] <- "V6-V8"
arch.all$V10[arch.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(arch.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of MBARI MT SSU rRNA (Archaea)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/MBARI-ARCH-MT.pdf", width=10, height=8)
p
# Out:
# plot without title

# %%
#MBARI ARCH MT
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Saanich_Inlet/compute-workflow-intermediate/200304_Saanich_complete_MG.tsv", header=FALSE)
arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="6-mismatch" & V4!="1389F" & V4!="27F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

arch.all$V10[arch.all$V4=="515Y"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="806RB"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926R"] <- "V4 / V4-V5"

#arch.all$V10[arch.all$V4=="27F"] <- "V1-V2"
#arch.all$V10[arch.all$V4=="338R"] <- "V1-V2"

arch.all$V10[arch.all$V4=="341F"] <- "V3-V4"
arch.all$V10[arch.all$V4=="785R"] <- "V3-V4"

arch.all$V10[arch.all$V4=="926wF"] <- "V6-V8"
arch.all$V10[arch.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(arch.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Saanich inlet MG SSU rRNA (Archaea)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Saanich-ARCH.pdf", width=10, height=8)
p
# Out:
# plot without title

# %%
#Guaymas ARCH
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Guaymas_Dombrowski_2018/compute-workflow-intermediate/200810_Guaymas_complete_MG.tsv", header=FALSE)
arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="6-mismatch" & V4!="1389F" & V4!="27F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","515Yp","806RB","926R","926Rp","926wF","1392R", "807F","1050R"))

arch.all$V10[arch.all$V4=="515Y"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="806RB"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926R"] <- "V4 / V4-V5"

arch.all$V10[arch.all$V4=="515Yp"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926Rp"] <- "V4 / V4-V5"

#arch.all$V10[arch.all$V4=="27F"] <- "V1-V2"
#arch.all$V10[arch.all$V4=="338R"] <- "V1-V2"

arch.all$V10[arch.all$V4=="341F"] <- "V3-V4"
arch.all$V10[arch.all$V4=="785R"] <- "V3-V4"

arch.all$V10[arch.all$V4=="926wF"] <- "V6-V8"
arch.all$V10[arch.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(arch.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Guaymas Sediment MG SSU rRNA (Archaea)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text.y = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        axis.text.x = element_text(size = rel(1.3), angle=90),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )

ggsave(file="./plots/Guaymas-ARCH.pdf", width=10, height=8)
p
# Out:
# plot without title

# %%
#Guaymas Bacteria
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Guaymas_Dombrowski_2018/compute-workflow-intermediate/200810_Guaymas_complete_MG.tsv", header=FALSE)
bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="1389F" & V4!="1510R" & V4!="V4RB" & V4!="V4R"), ]
bact.all$V4=factor(bact.all$V4, levels=c("27F","338R","341F","785R","515Y","806RB","926R","V4F","V4R","V4RB","926wF","1392R","807F","1050R","515Yp","926Rp"))

bact.all$V10[bact.all$V4=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926R"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="515Yp"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V4=="926Rp"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V4=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V4=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V4=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V4=="785R"] <- "V3-V4"

bact.all$V10[bact.all$V4=="807F"] <- "V5-V6"
bact.all$V10[bact.all$V4=="1050R"] <- "V5-V6"

bact.all$V10[bact.all$V4=="926wF"] <- "V6-V8"
bact.all$V10[bact.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(bact.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of Guaymas Sediment MG SSU rRNA (Bacteria)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text.y = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        axis.text.x = element_text(size = rel(1.3), angle=90),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
p
ggsave(file="./plots/Guaymas-BACT-NON-CYANO.pdf", width=10, height=8)
# Out:
# plot without title

# %%
#Malaspina ARCH
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Malaspina_Acinas_2019/compute-workflow-intermediate/200123_summary.tsv", header=FALSE)
arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="6-mismatch" & V4!="1389F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R"))

arch.all$V10[arch.all$V4=="515Y"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="806RB"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926R"] <- "V4 / V4-V5"

#arch.all$V10[arch.all$V4=="27F"] <- "V1-V2"
#arch.all$V10[arch.all$V4=="338R"] <- "V1-V2"

arch.all$V10[arch.all$V4=="341F"] <- "V3-V4"
arch.all$V10[arch.all$V4=="785R"] <- "V3-V4"

arch.all$V10[arch.all$V4=="926wF"] <- "V6-V8"
arch.all$V10[arch.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(arch.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of bioGEOTRACES MG SSU rRNA (Archaea)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/Malaspina-ARCH.pdf", width=10, height=8)
p
# Out:
# plot without title

# %%
library(ggplot2)


all.summary <- read.delim("/home/jesse/MG-primer-eval/bioGEOTRACES/compute-workflow-intermediate/200808_incomplete.tsv", header=FALSE)
arch.all <- all.summary[with(all.summary, V3=="ARCH" & V6>=10 & V9!="NA" & V5!="6-mismatch" & V4!="1389F" & V4!="338R" & V4!="1510R" & V4!="V4F" & V4!="V4R" & V4!="V4RB"), ]
arch.all$V4=factor(arch.all$V4, levels=c("341F","785R","515Y","806RB","926R","926wF","1392R", "807F","1050R","515Yp","926Rp"))

arch.all$V10[arch.all$V4=="515Y"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="515Yp"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="806RB"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926R"] <- "V4 / V4-V5"
arch.all$V10[arch.all$V4=="926Rp"] <- "V4 / V4-V5"

#arch.all$V10[arch.all$V4=="27F"] <- "V1-V2"
#arch.all$V10[arch.all$V4=="338R"] <- "V1-V2"

arch.all$V10[arch.all$V4=="341F"] <- "V3-V4"
arch.all$V10[arch.all$V4=="785R"] <- "V3-V4"

arch.all$V10[arch.all$V4=="807F"] <- "V5-V6"
arch.all$V10[arch.all$V4=="1050R"] <- "V5-V6"

arch.all$V10[arch.all$V4=="926wF"] <- "V6-V8"
arch.all$V10[arch.all$V4=="1392R"] <- "V6-V8"

p <- ggplot(arch.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of bioGEOTRACES MG SSU rRNA (Archaea)", fill="Mismatches") +
facet_grid(. ~ V10, scales="free")
p<-p+scale_y_continuous(breaks=seq(0,1,0.1))
p<-p+ theme_bw() + theme(plot.title = element_text(hjust = 0.5), panel.border = element_rect(colour = "black", fill=NA, size=0.5), 
                        panel.grid.major.y = element_line(linetype="dashed", colour = "grey", size=0.5),
                        panel.grid.minor = element_blank(), panel.grid.major.x = element_blank(), 
                        axis.title = element_text(size = rel(1.5)), #axis.line = element_line(colour = "black"),
                        axis.text.y = element_text(size = rel(1.3)), strip.text = element_text(size = rel(1.3)),
                        axis.text.x = element_text(size = rel(1.3), angle=90),
                        legend.text = element_text(size = rel(1.3)), legend.title = element_text(size = rel(1.3),hjust = 0.5),
                        legend.box.background = element_rect(colour = "black", fill=NA, size=0.5) )
ggsave(file="./plots/bioGEOTRACES-ARCH.pdf", width=10, height=8)
p
# Out:
# plot without title

# %% [markdown]
# # Overall EUK fraction for a non size-fractionated dataset (bioGEOTRACES)

# %%
library(ggplot2)

eukfrac <- read.delim("/home/jesse/MG-primer-eval/bioGEOTRACES/eukFrac/200721_EUK_frac_phyloFlash.tsv", header=FALSE)
print(mean(eukfrac$V2))
print(sd(eukfrac$V2))
print(max(eukfrac$V2))
print(min(eukfrac$V2))


#bact.all <- all.summary[with(all.summary, V3=="BACT-NON-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="V4RB"), ]

p <- ggplot(eukfrac, aes(y=V2, x="")) +
geom_violin()
p <- p + labs(x="", y="Fraction of eukaryotic metagenomic SSU rRNA fragments\n(out of total 16S + 18S)", fill="Mismatches", title=expression(paste("Fraction of 18S SSU rRNA from BiHoBa Metagenomes"))) + theme(plot.title = element_text(hjust = 0.5)) 
p<-p + geom_boxplot(width=0.1, outlier.size=1)
ggsave(file="./plots/bioGEOTRACES-eukFrac-phyloFlash.pdf")
p
# Out:
# [1] 0.1951506
# [1] 0.09315653
# [1] 0.7049443
# [1] 0.02395591
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#Malaspina
library(ggplot2)

all.summary <- read.delim("/home/jesse/MG-primer-eval/Malaspina_Acinas_2019/compute-workflow-intermediate/200123_summary.tsv", header=FALSE)
cyano.all <- all.summary[with(all.summary, V3=="BACT-CYANO" & V6>=10 & V5!="6-mismatch" & V4!="V4F" & V4!="V4RB" & V4!="1389F" & V4!="1510R"), ]

cyano.all$V10[cyano.all$V4=="515Y"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="806RB"] <- "V4 / V4-V5"
cyano.all$V10[cyano.all$V4=="926R"] <- "V4 / V4-V5"

cyano.all$V10[cyano.all$V4=="27F"] <- "V1-V2"
cyano.all$V10[cyano.all$V4=="338R"] <- "V1-V2"

cyano.all$V10[cyano.all$V4=="341F"] <- "V3-V4"
cyano.all$V10[cyano.all$V4=="785R"] <- "V3-V4"

p <- ggplot(cyano.all, aes(x=V4, y=V9, fill=V5)) +
geom_boxplot() + labs(x="Primer", y="Coverage of metagenomic SSU rRNA fragments", fill="Mismatches", title=expression(paste("bioGEOTRACES Primer Coverage for Cyanobacteria (incl. plastids; > 0.22 ", mu, "M fraction, n=610)"))) + 
theme(plot.title = element_text(hjust = 0.5)) + facet_grid(. ~ V10, scales="free")
ggsave(file="./plots/Malaspina-BACT-CYANO.pdf", plot=p, width=10, height=8)
p
# Out:
# plot without title

# %% [markdown]
# # Tara from miTAGs, no quality filtering

# %%
library(ggplot2)

all.summary.less27F <- read.delim("/home/jesse/MG-primer-eval/Tara-miTAGs/results/190502_Tara-miTAGs_results.tsv", header=FALSE)
bact.all <- all.summary.less27F[with(all.summary.less27F, V2=="BACT-NON-CYANO" & V5>=10 & V4!="6-mismatch" & V3!="V4F" & V3!="V4RB"), ]

bact.all$V10[bact.all$V3=="515Y"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V3=="806RB"] <- "V4 / V4-V5"
bact.all$V10[bact.all$V3=="926R"] <- "V4 / V4-V5"

bact.all$V10[bact.all$V3=="27F"] <- "V1-V2"
bact.all$V10[bact.all$V3=="338R"] <- "V1-V2"

bact.all$V10[bact.all$V3=="341F"] <- "V3-V4"
bact.all$V10[bact.all$V3=="785R"] <- "V3-V4"

p <- ggplot(bact.all, aes(x=V3, y=V8, fill=V4)) +
geom_boxplot() + labs(x="Primer", y="Coverage of metagenomic SSU rRNA fragments", fill="Mismatches", title="Tara Primer Coverage for Bacteria (miTAGs, no sequence QC; bacterial and protist fractions, n=235)") +
theme(plot.title = element_text(hjust = 0.5)) + facet_grid(. ~ V10, scales="free")
ggsave(file="./plots/Tara-miTAG-BACT-NON-CYANO.svg", plot=p, width=10, height=8)
p
# Out:
# plot without title
